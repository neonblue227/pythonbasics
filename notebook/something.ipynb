# %% [markdown]
# ## print and functions

# %%
print("helloworld")
# Out:
# helloworld

# %%
txt = "helloworld"
print(txt, "is a string" ,sep=" ")
# Out:
# helloworld is a string

# %%
def printname(name):
    print("Hello my name is", name)
name = "Neon"
printname(name)
# Out:
# Hello my name is Neon

# %% [markdown]
# ## Modify String

# %%
txt = "text"
text1 = txt.upper()
print(text1)
# Out:
# TEXT

# %%
text = "i like apples"
result = text.replace("apples", "oranges")
print(result)
# Out:
# i like oranges

# %%
tx1 = "2"
tx2 = "ez"
print(tx1,end="")
print(tx2)
# Out:
# 2ez

# %%
tx1 = "hello"
tx2 = "world"
print(tx1,tx2,sep=" " , end="\n")
# Out:
# hello world!

# %%
print("hello\nstudent")
# Out:
# hello
# student

# %%
print("hello", end="\r")
print("world")
# Out:
# world

# %% [markdown]
# 2.

# %%
txt = 1
txt2 = 2
print(txt,end="")
print(txt2)
# Out:
# 12

# %% [markdown]
# ## types

# %%
float1 = 1.5
float2 = 2.5
float2 = float(float2)

# %%
print(type(float1))
# Out:
# <class 'float'>

# %%
if type(float1) == float:
    print("float1 is a float")

# %% [markdown]
# ## input

# %%
input_num = int(input("Enter a number: "))
print("You entered:", input_num)
# Out:
# You entered: 20

# %%
inte = 34
print(type(inte))
print(inte)

new = 34.5
print(type(new))
print(new)
# Out:
# <class 'int'>
# 34
# <class 'float'>
# 34.5
